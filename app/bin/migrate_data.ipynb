# %%
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from google.cloud import storage
import os
import io
import pickle


def authenticate():
    creds = None
    # Check if token file exists
    if os.path.exists("token.pickle"):
        with open("token.pickle", "rb") as token:
            creds = pickle.load(token)

    # If credentials don't exist or are invalid, get new ones
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            # Load client secrets from downloaded file
            flow = InstalledAppFlow.from_client_secrets_file(
                "/workspaces/BRIDGE/client_secret_oauth2_bridge.json", SCOPES
            )
            # Run the authorization flow
            creds = flow.run_local_server(port=34817)

        # Save the credentials for future runs
        with open("token.pickle", "wb") as token:
            pickle.dump(creds, token)

    return creds


# Define the scopes your application needs
SCOPES = ["https://www.googleapis.com/auth/drive.readonly"]

# %%
# Constants
DRIVE_FOLDER_ID = "1lUo6mgTbdDhHZs8gOODXERycOm2mEVrn"
BUCKET_NAME = "bridge-ml-training"
SERVICE_ACCOUNT_FILE = "/workspaces/BRIDGE/bridge-service-account.json"

# Setup clients
creds = authenticate()
drive = build("drive", "v3", credentials=creds)
gcs = storage.Client.from_service_account_json(SERVICE_ACCOUNT_FILE)
bucket = gcs.bucket(BUCKET_NAME)

# List files in folder
files = (
    drive.files()
    .list(q=f"'{DRIVE_FOLDER_ID}' in parents", fields="files(id, name)")
    .execute()
    .get("files", [])
)

for file in files:
    print(f"Found file: {file['name']} ({file['id']})")
    if not file["name"].endswith(".csv"):
        continue

    # Convert filename (aa -> 1, ab -> 2, etc.)
    name = file["name"].split(".")[0]
    index = (ord(name[0]) - ord("a")) * 26 + (ord(name[1]) - ord("a") + 1)
    print(f"Index: {index}")

    # Download from Drive
    request = drive.files().get_media(fileId=file["id"])
    content = io.BytesIO()
    downloader = MediaIoBaseDownload(content, request)
    done = False
    while not done:
        _, done = downloader.next_chunk()

    # Upload to GCS
    content.seek(0)
    blob = bucket.blob(f"pretraining/{index}/data_{index}.csv")
    blob.upload_from_file(content)
    print(
        f"Uploaded {file['name']} → gs://{BUCKET_NAME}/pretraining/{index}/data_{index}.csv"
    )
# Out:
# Found file: bx.csv (15Qbck_oNrZ3Mo-kx1gJW_LsMWekFuc37)
# Index: 50
# Uploaded bx.csv → gs://bridge-ml-training/pretraining/50/data_50.csv
# Found file: bq.csv (15i6OWL6tHzKQ3TOXI96hdCeNPRsDh5nW)
# Index: 43
# Uploaded bq.csv → gs://bridge-ml-training/pretraining/43/data_43.csv
# Found file: bt.csv (1AOI6OCXWMsJ5a-ubwF2Z7H9UJapywVJj)
# Index: 46
# Uploaded bt.csv → gs://bridge-ml-training/pretraining/46/data_46.csv
# Found file: bp.csv (1-4PzxSGDENDMxGsf74kmQu1v6PGoZNh-)
# Index: 42
# Uploaded bp.csv → gs://bridge-ml-training/pretraining/42/data_42.csv
# Found file: br.csv (1R6MFynfg4IVBTAIQLOkGDlLfYI5EY45m)
# Index: 44
# Uploaded br.csv → gs://bridge-ml-training/pretraining/44/data_44.csv
# Found file: bu.csv (1gfsCcgTQLZ9loyWgqu1Qt77sQltOwtDH)
# Index: 47
# Uploaded bu.csv → gs://bridge-ml-training/pretraining/47/data_47.csv
# Found file: bw.csv (1sodxLiaQM8NN4V8d8_m3u9wT8MUirdil)
# Index: 49
# Uploaded bw.csv → gs://bridge-ml-training/pretraining/49/data_49.csv
# Found file: bs.csv (1jadO_zTDwCZsYUwQyM7YdMDXDZqjvPlp)
# Index: 45
# Uploaded bs.csv → gs://bridge-ml-training/pretraining/45/data_45.csv
# Found file: bv.csv (15SwxTPPeOmaeLyJupSChdeXqoAUUmDsl)
# Index: 48
# Uploaded bv.csv → gs://bridge-ml-training/pretraining/48/data_48.csv
# Found file: bn.csv (1UNNE5ugcLWjvvpMhi5ftABvIqlTqya31)
# Index: 40
# Uploaded bn.csv → gs://bridge-ml-training/pretraining/40/data_40.csv
# Found file: bi.csv (1T2uJY1CoiiRZbs6dAkW8u-fC6iKpF3lx)
# Index: 35
# Uploaded bi.csv → gs://bridge-ml-training/pretraining/35/data_35.csv
# Found file: bh.csv (1vPhdbxv7M6rxFyTOqc5vbmWQl2UZjxpG)
# Index: 34
# Uploaded bh.csv → gs://bridge-ml-training/pretraining/34/data_34.csv
# Found file: bj.csv (1GLffI2XqAaeyiOjqqTJl6yA_1SPPx-F0)
# Index: 36
# Uploaded bj.csv → gs://bridge-ml-training/pretraining/36/data_36.csv
# Found file: bm.csv (1nN2tAlPEq0N3JCxwslRnrEi7-DLbMXmu)
# Index: 39
# Uploaded bm.csv → gs://bridge-ml-training/pretraining/39/data_39.csv
# Found file: bk.csv (18UD7F6txKqEdh1KNSX5-vM7NnL2whQ3_)
# Index: 37
# Uploaded bk.csv → gs://bridge-ml-training/pretraining/37/data_37.csv
# Found file: bg.csv (1G8PES1OSONkIS3KfFHeAnjQZF-b3xqCI)
# Index: 33
# Uploaded bg.csv → gs://bridge-ml-training/pretraining/33/data_33.csv
# Found file: bo.csv (1-ItoTlaFZq746U_Brt_qkasoC4Am1Rm6)
# Index: 41
# Uploaded bo.csv → gs://bridge-ml-training/pretraining/41/data_41.csv
# Found file: bl.csv (1YcncAL0JhRXK73PzRUV2bZl7j7ziaO8k)
# Index: 38
# Uploaded bl.csv → gs://bridge-ml-training/pretraining/38/data_38.csv
# Found file: ba.csv (1zjIOKME-ejurwW-sh_VZKU8drGhVrU3i)
# Index: 27
# Uploaded ba.csv → gs://bridge-ml-training/pretraining/27/data_27.csv
# Found file: bd.csv (1djOt0D9uw9CtkZsDzORDx4whGGe-X-S7)
# Index: 30
# Uploaded bd.csv → gs://bridge-ml-training/pretraining/30/data_30.csv
# Found file: bf.csv (1Yv8OVFdkxdwyX1AuENNVmc9pUcLr5sPK)
# Index: 32
# Uploaded bf.csv → gs://bridge-ml-training/pretraining/32/data_32.csv
# Found file: bb.csv (1wWSIf2UEEooSUxoFL_rVvFmMkRKta3vW)
# Index: 28
# Uploaded bb.csv → gs://bridge-ml-training/pretraining/28/data_28.csv
# Found file: be.csv (16I8MrjiJ9cofMn_E4xfEnPbVjDP29Cpl)
# Index: 31
# Uploaded be.csv → gs://bridge-ml-training/pretraining/31/data_31.csv
# Found file: bc.csv (18VNHRJXEPBV-vgcQou_3jxBRo6O8v1yy)
# Index: 29
# Uploaded bc.csv → gs://bridge-ml-training/pretraining/29/data_29.csv
# Found file: az.csv (1_TakZqk3j2XFgaII5Fe2Ju5e-tCDGLtC)
# Index: 26
# Uploaded az.csv → gs://bridge-ml-training/pretraining/26/data_26.csv
# Found file: ay.csv (1jgyClH39rfGzqP6GPmheHmqn08pjMdmC)
# Index: 25
# Uploaded ay.csv → gs://bridge-ml-training/pretraining/25/data_25.csv
# Found file: ax.csv (1oi2NfWmAg8YaMO5eV6DhOd0vkB3pTJvG)
# Index: 24
# Uploaded ax.csv → gs://bridge-ml-training/pretraining/24/data_24.csv
# Found file: ao.csv (1yz3wFURNNTQWQxg7Up9WLCYrAJMpxSuf)
# Index: 15
# Uploaded ao.csv → gs://bridge-ml-training/pretraining/15/data_15.csv
# Found file: aq.csv (1St40YNBocDTIf_QnaAcn0qdxwHLlJfes)
# Index: 17
# Uploaded aq.csv → gs://bridge-ml-training/pretraining/17/data_17.csv
# Found file: av.csv (1vZy2kWuw7KetIeCux0HurMooSDH6cctm)
# Index: 22
# Uploaded av.csv → gs://bridge-ml-training/pretraining/22/data_22.csv
# Found file: as.csv (1KgFghakxzXqalccWKMBhZfqt4nAMrmEO)
# Index: 19
# Uploaded as.csv → gs://bridge-ml-training/pretraining/19/data_19.csv
# Found file: ap.csv (1cpX9-4JY-PSiPA_i2EOpwZMgQ3XVsw3l)
# Index: 16
# Uploaded ap.csv → gs://bridge-ml-training/pretraining/16/data_16.csv
# Found file: au.csv (11U98tlulzT4MmN8PlgXoKvljdqnj-8Ej)
# Index: 21
# Uploaded au.csv → gs://bridge-ml-training/pretraining/21/data_21.csv
# Found file: ar.csv (1AGZUP6-Gf35_Hf3o_jtD1QuMOAKtQLVI)
# Index: 18
# Uploaded ar.csv → gs://bridge-ml-training/pretraining/18/data_18.csv
# Found file: at.csv (1daI-MEdH7HI_5N8dVPgi6mad525bCXgw)
# Index: 20
# Uploaded at.csv → gs://bridge-ml-training/pretraining/20/data_20.csv
# Found file: aw.csv (1rROi3QM18iwGA8VjAxCbOtweal74J616)
# Index: 23
# Uploaded aw.csv → gs://bridge-ml-training/pretraining/23/data_23.csv
# Found file: ak.csv (1rSXCaZD260uDR1rI8cHcOOLrBhKSLG2p)
# Index: 11
# Uploaded ak.csv → gs://bridge-ml-training/pretraining/11/data_11.csv
# Found file: ag.csv (17CG-iNX9TEZmd-KtOfNJaATnhdFBK8FK)
# Index: 7
# Uploaded ag.csv → gs://bridge-ml-training/pretraining/7/data_7.csv
# Found file: ai.csv (1OQugqToJwb8d2teyUPQn9tFnrx7Ivb8F)
# Index: 9
# Uploaded ai.csv → gs://bridge-ml-training/pretraining/9/data_9.csv
# Found file: an.csv (1JJWkd4Sm2A47fX55451zIEP5Anr1mxVT)
# Index: 14
# Uploaded an.csv → gs://bridge-ml-training/pretraining/14/data_14.csv
# Found file: al.csv (19qyafEVJVG6uQCGFl_02-FR4UbrFSP0O)
# Index: 12
# Uploaded al.csv → gs://bridge-ml-training/pretraining/12/data_12.csv
# Found file: aj.csv (1606JZr1bsLnG1KrGmX-H7S03RcBSMdW4)
# Index: 10
# Uploaded aj.csv → gs://bridge-ml-training/pretraining/10/data_10.csv
# Found file: ah.csv (1cAE7_W6nhTq1ttqfaHYnQwV5sHRC_v5y)
# Index: 8
# Uploaded ah.csv → gs://bridge-ml-training/pretraining/8/data_8.csv
# Found file: af.csv (1AE6CZbGoxSiGOVLB3bah4tqiVZLQNTD2)
# Index: 6
# Uploaded af.csv → gs://bridge-ml-training/pretraining/6/data_6.csv
# Found file: am.csv (1wk_XrFtzjEYSy-6qjCRITZEgh8ija5v3)
# Index: 13
# Uploaded am.csv → gs://bridge-ml-training/pretraining/13/data_13.csv
# Found file: ae.csv (11YLRNYq3Vc55-yQMbGWIaYnZo0AFr7Kv)
# Index: 5
# Uploaded ae.csv → gs://bridge-ml-training/pretraining/5/data_5.csv
# Found file: ab.csv (1LD65Mil4x36BbewcSnUSuYm6e7k0t462)
# Index: 2
# Uploaded ab.csv → gs://bridge-ml-training/pretraining/2/data_2.csv
# Found file: ac.csv (1b3f4c_exqYn7k8dUpP2HF7FFEPauia7L)
# Index: 3
# Uploaded ac.csv → gs://bridge-ml-training/pretraining/3/data_3.csv
# Found file: aa.csv (1NOfELF4HyJkKnLX7-k4LJ-MZIR0vzmgM)
# Index: 1
# Uploaded aa.csv → gs://bridge-ml-training/pretraining/1/data_1.csv
# Found file: ad.csv (1ZQrd07qyp7aAQUJXBm9O4zeMZC12t4Py)
# Index: 4
# Uploaded ad.csv → gs://bridge-ml-training/pretraining/4/data_4.csv
